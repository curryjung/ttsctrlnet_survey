# %%
import os

audio_dir = "/mnt/CINELINGO_BACKUP/jaeseok/anycode/video_survey/audio"


emochange_results_dir = os.path.join(audio_dir, "emochange_results")
emochange_ref_dir = os.path.join(audio_dir, "emochange_ref")


model_name_list = os.listdir(emochange_results_dir)

for model_name in model_name_list:
    # if not model_name == "voicebox":
    #     continue
    for file in os.listdir(os.path.join(emochange_results_dir, model_name)):
        if file.endswith(".wav"):
            name = file.split("_")[:3]
            name = "_".join(name)
            os.rename(os.path.join(emochange_results_dir, model_name, file), os.path.join(emochange_results_dir, model_name, name + ".wav"))

# %%
import os

audio_dir = "/mnt/CINELINGO_BACKUP/jaeseok/anycode/video_survey/audio"


emochange_results_dir = os.path.join(audio_dir, "jvnv_results")
emochange_ref_dir = os.path.join(audio_dir, "jvnv_ref")


for file in sorted(os.listdir(emochange_ref_dir)):
    if file.endswith(".wav"):
        name = file.split("_")[:3]
        name = "_".join(name)
        print(name)
        # os.rename(os.path.join(emochange_ref_dir, file), os.path.join(emochange_ref_dir, name + ".wav"))


model_name_list = os.listdir(emochange_results_dir)

for model_name in model_name_list:
    for file in sorted(os.listdir(os.path.join(emochange_results_dir, model_name))):
        if file.endswith(".wav"):
            name = file.split("_")[:3]
            name = "_".join(name)
            print(name)
            # os.rename(os.path.join(emochange_results_dir, model_name, file), os.path.join(emochange_results_dir, model_name, name + ".wav"))
# Out:
# JVNV_F1_angry
# JVNV_F1_disgusted
# JVNV_F1_fearful
# JVNV_F1_happy
# JVNV_F1_sad
# JVNV_M1_happy
# JVNV_M1_sad
# JVNV_M2_fearful
# JVNV_F1_surprised
# JVNV_M1_surprised
# JVNV_M1_angry
# JVNV_M1_disgusted
# JVNV_F1_happy
# JVNV_F1_sad
# JVNV_F1_surprised
# JVNV_F1_angry
# JVNV_F1_disgusted
# JVNV_M1_happy
# JVNV_F1_fearful
# JVNV_M2_fearful
# JVNV_M1_angry
# JVNV_M1_disgusted
# JVNV_M1_sad
# JVNV_F1_disgusted
# JVNV_F1_angry
# JVNV_F1_fearful
# JVNV_M1_angry
# JVNV_M1_disgusted
# JVNV_M1_happy
# JVNV_M1_sad
# JVNV_F1_happy
# JVNV_F1_sad
# JVNV_F1_surprised
# JVNV_M2_fearful
# JVNV_M2_fearful
# JVNV_F1_fearful
# JVNV_M1_disgusted
# JVNV_F1_disgusted
# JVNV_M1_surprised
# JVNV_F1_surprised
# JVNV_M1_angry
# JVNV_F1_angry
# JVNV_M1_sad
# JVNV_F1_sad
# JVNV_M1_happy
# JVNV_F1_happy
# JVNV_F1_happy
# JVNV_M1_happy
# JVNV_F1_sad
# JVNV_M1_sad
# JVNV_F1_angry
# JVNV_M1_angry
# JVNV_F1_surprised
# JVNV_M1_surprised
# JVNV_F1_disgusted
# JVNV_M1_disgusted
# JVNV_F1_fearful
# JVNV_M2_fearful
# JVNV_F1_happy
# JVNV_M1_happy
# JVNV_F1_sad
# JVNV_M1_sad
# JVNV_F1_angry
# JVNV_M1_angry
# JVNV_F1_surprised
# JVNV_M1_surprised
# JVNV_F1_disgusted
# JVNV_M1_disgusted
# JVNV_F1_fearful
# JVNV_M2_fearful
# JVNV_F1_happy
# JVNV_M1_happy
# JVNV_F1_sad
# JVNV_M1_sad
# JVNV_F1_angry
# JVNV_M1_angry
# JVNV_F1_surprised
# JVNV_M1_surprised
# JVNV_F1_disgusted
# JVNV_M1_disgusted
# JVNV_F1_fearful
# JVNV_M2_fearful
